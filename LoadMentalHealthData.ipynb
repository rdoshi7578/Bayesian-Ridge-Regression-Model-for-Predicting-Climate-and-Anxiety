# %%
import pandas as pd
mental = pd.read_csv('/Users/norahocallaghan/Desktop/mental_health_ed_visits.csv')

# %%
mental.head()
# Out:
#   month_end          condition demographics_type demographics_values  \
# 0   2025-12  Anxiety Disorders               Age         12-17 years
# 1   2025-12  Anxiety Disorders               Age         18-34 years
# 2   2025-12  Anxiety Disorders               Age         35-64 years
# 3   2025-12  Anxiety Disorders               Age           65+ years
# 4   2025-12  Anxiety Disorders               Age                 All
#
#    rate_per_100000_visits
# 0                    1817
# 1                    2542
# 2                    2874
# 3                    2657
# 4                    2338
